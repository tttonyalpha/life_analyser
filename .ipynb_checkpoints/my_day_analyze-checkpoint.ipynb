# %%
#!pip install gspread oauth2client

# %%
#!jupyter labextension install jupyterlab-plotly

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

# %matplotlib inline

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %matplotlib inline
# %config InlineBackend.figure_formats = ['retina']
sns.set(rc={'figure.figsize':(15, 7)}, style='darkgrid')

scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('my-day-analyze-f7d79d96a0ff.json', scope)
gc = gspread.authorize(credentials)

# открытие таблицы по ссылке или имени
worksheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1HicRqzhoYOBCv0WRDP6UZdppTDSUFr4ifdWU_WzQq6c/edit?resourcekey#gid=898072817').sheet1

# %%
# получение всех значений в виде списка списков
data = worksheet.get_all_values()

# создание DataFrame из списка списков
df = pd.DataFrame(data[1:], columns=data[0])

# %%
from datetime import datetime
current_dateTime = datetime.now()

# %%
df.columns
# Out:
# Index(['Timestamp', 'Что делал?', 'Длительность (мин)',
#        'Насколько ты удовлетворен тем, как сейчас проводишь время?', '',
#        'Насколько ты устал?', 'Оцени свой уровень стресса ',
#        'Насколько ты мотивирован?', 'Насколько ты сконцентрирован?',
#        'Что можно сделать сейчас, чтобы почувствовать себя лучше? ',
#        'Что тебе помогает сейчас чувствовать себя лучше?',
#        'Что тебе сейчас нравится?', 'Что тебе сейчас не нравится?',
#        'Что отвлекает?', 'Заметки: ',
#        'Насколько ты хорошо себя чувствуешь физически'],
#       dtype='object')

# %%
df['Timestamp'] = pd.to_datetime(df.Timestamp)

# %%
print(datetime.now().date())
# Out:
# 2023-03-24

# %%
df_now = df[df.Timestamp.apply(lambda x: x.date()) == datetime.now().date()]

# %%
df_cur = df[df.Timestamp.apply(lambda x: x.date()) == datetime.strptime('2023-03-20', '%Y-%m-%d').date()]

# %%
numeric = ['Длительность (мин)',
       'Насколько ты удовлетворен тем, как сейчас проводишь время?',
       'Насколько ты устал?', 'Оцени свой уровень стресса ',
       'Насколько ты мотивирован?', 'Насколько ты сконцентрирован?',
       'Насколько ты хорошо себя чувствуешь физически']

# %%
df_cur.tail(4)
# Out:
#               Timestamp         Что делал? Длительность (мин)  \
# 210 2023-03-20 15:56:42                 ML                 45
# 211 2023-03-20 20:48:21  Quantum mechanics                120
# 212 2023-03-20 22:25:53                 ML                 20
# 213 2023-03-20 23:24:21  Quantum mechanics                 40
#
#     Насколько ты удовлетворен тем, как сейчас проводишь время?    \
# 210                                                  6
# 211                                                  4
# 212                                                  7
# 213                                                  3
#
#     Насколько ты устал? Оцени свой уровень стресса  Насколько ты мотивирован?  \
# 210                   2                           0                         6
# 211                   1                           1                         5
# 212                   0                           0                         6
# 213                   0                           2                         3
#
#     Насколько ты сконцентрирован?  \
# 210                             5
# 211                             6
# 212                             6
# 213                             5
#
#     Что можно сделать сейчас, чтобы почувствовать себя лучше?   \
# 210
# 211
# 212
# 213
#
#     Что тебе помогает сейчас чувствовать себя лучше?  \
# 210
# 211
# 212
# 213
#
#     Что тебе сейчас нравится? Что тебе сейчас не нравится? Что отвлекает?  \
# 210
# 211
# 212
# 213
#
#     Заметки:  Насколько ты хорошо себя чувствуешь физически
# 210                                                       5
# 211                                                       5
# 212                                                       6
# 213                                                       5

# %%
cleaned_indexes = df_cur[numeric].apply(lambda x: np.vectorize(lambda x: x if x.isnumeric() else np.nan)(x)).dropna().index

# %%
clean_df = df.iloc[cleaned_indexes]
clean_df[numeric] = clean_df[numeric].astype(int)
clean_df['Длительность (мин)'] = clean_df['Длительность (мин)']/60
# Out:
# /home/tonyalpha/.local/lib/python3.8/site-packages/pandas/core/frame.py:3636: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-44-cd7827f5501b>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_for_pie = pd.DataFrame(clean_df.groupby(by=['Что делал?'])['Длительность (мин)'].sum()).reset_index()
#data_for_pie = data_for_pie.sort_values(by = 'Длительность (мин)')
total_time = clean_df['Длительность (мин)'].sum()
mean_concentration = clean_df['Насколько ты сконцентрирован?'].mean()
mean_motivation = clean_df['Насколько ты мотивирован?'].mean()

mean_exhaustion = clean_df['Насколько ты устал?'].mean()
mean_stress = clean_df['Оцени свой уровень стресса '].mean()
mean_motivation = clean_df['Насколько ты хорошо себя чувствуешь физически'].mean()

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'iframe'

fig1 = px.pie(data_for_pie, values='Длительность (мин)', names='Что делал?')
fig1.update_traces(textinfo='label+percent+value', texttemplate='%{label} (%{percent})<br>%{value:.2f} h')
fig1.update_layout(
    title={
        'text': f'Total time: {total_time:.2f} hours Concentration = {mean_concentration:.2f}/10 Motivation = {mean_motivation:.2f}/10 Exhaustion = {mean_exhaustion:.2f}/10 Stress = {mean_stress:.2f}/10 ',
        'y':0.95,
        'x':0.45,
        'xanchor': 'center',
        'yanchor': 'top'})
fig1.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_91.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df.tail(10)
# Out:
#               Timestamp         Что делал? Длительность (мин)  \
# 212 2023-03-20 22:25:53                 ML                 20
# 213 2023-03-20 23:24:21  Quantum mechanics                 40
# 214 2023-03-21 14:42:25                 ML                 30
# 215 2023-03-21 17:12:07                 ML                 45
# 216 2023-03-21 19:28:46                 ML                 45
# 217 2023-03-21 20:00:55                 ML                 30
# 218 2023-03-21 22:47:32                 ML                 30
# 219 2023-03-21 23:39:59                 ML                 30
# 220 2023-03-22 00:22:43                 ML                 25
# 221 2023-03-22 14:34:45          Chemistry                 45
#
#     Насколько ты удовлетворен тем, как сейчас проводишь время?    \
# 212                                                  7
# 213                                                  3
# 214                                                  7
# 215                                                  6
# 216                                                  6
# 217                                                  6
# 218                                                  6
# 219                                                  4
# 220                                                  4
# 221                                                  4
#
#     Насколько ты устал? Оцени свой уровень стресса  Насколько ты мотивирован?  \
# 212                   0                           0                         6
# 213                   0                           2                         3
# 214                   0                           0                         7
# 215                   0                           0                         6
# 216                   0                           0                         6
# 217                   0                           1                         7
# 218                   0                           0                         6
# 219                   0                           0                         5
# 220                   0                           1                         5
# 221                   1                           1                         4
#
#     Насколько ты сконцентрирован?  \
# 212                             6
# 213                             5
# 214                             6
# 215                             6
# 216                             6
# 217                             6
# 218                             4
# 219                             4
# 220                             5
# 221                             5
#
#     Что можно сделать сейчас, чтобы почувствовать себя лучше?   \
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
#
#     Что тебе помогает сейчас чувствовать себя лучше?  \
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
#
#     Что тебе сейчас нравится? Что тебе сейчас не нравится? Что отвлекает?  \
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
#
#     Заметки:  Насколько ты хорошо себя чувствуешь физически
# 212                                                       6
# 213                                                       5
# 214                                                       6
# 215                                                       5
# 216                                                       6
# 217                                                       6
# 218                                                       6
# 219                                                       6
# 220                                                       5
# 221                                                       5

# %%
# !pip3 install dash_bootstrap_components
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dash_bootstrap_components
#   Downloading dash_bootstrap_components-1.4.1-py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.6/220.6 kB 2.5 MB/s eta 0:00:000:00:010:00:01
# Requirement already satisfied: dash>=2.0.0 in /home/tonyalpha/.local/lib/python3.8/site-packages (from dash_bootstrap_components) (2.8.1)
# Requirement already satisfied: dash-table==5.0.0 in /home/tonyalpha/.local/lib/python3.8/site-packages (from dash>=2.0.0->dash_bootstrap_components) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/tonyalpha/.local/lib/python3.8/site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/tonyalpha/.local/lib/python3.8/site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /home/tonyalpha/.local/lib/python3.8/site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in /home/tonyalpha/.local/lib/python3.8/site-packages (from dash>=2.0.0->dash_bootstrap_components) (5.11.0)
# Requirement already satisfied: Jinja2>=3.0 in /home/tonyalpha/.local/lib/python3.8/site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (3.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /home/tonyalpha/.local/lib/python3.8/site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (6.0.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /home/tonyalpha/.local/lib/python3.8/site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.2.3)
# Requirement already satisfied: click>=8.0 in /home/tonyalpha/.local/lib/python3.8/site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /home/tonyalpha/.local/lib/python3.8/site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /home/tonyalpha/.local/lib/python3.8/site-packages (from plotly>=5.0.0->dash>=2.0.0->dash_bootstrap_components) (8.1.0)
# Requirement already satisfied: zipp>=0.5 in /home/tonyalpha/.local/lib/python3.8/site-packages (from importlib-metadata>=3.6.0->Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tonyalpha/.local/lib/python3.8/site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.1.2)
# Installing collected packages: dash_bootstrap_components
# Successfully installed dash_bootstrap_components-1.4.1
